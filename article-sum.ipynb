# %%
# !pip install nltk

# %%
import pandas as pd
import numpy as np
import spacy
from spacy.lang.en import English
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
from termcolor import colored
import random
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Load spaCy English model (download if not already installed)
nlp = English()

# Load the CSV data
df = pd.read_csv("/kaggle/input/tennis-csv/tennis.csv")

# Preprocess the text data
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stop words
    tokens = [token for token in tokens if token not in stopwords.words('english')]
    # Convert tokens back to a string
    return ' '.join(tokens)

df['article_text'] = df['article_text'].apply(preprocess_text)

# Tokenize sentences
sentences = []
for s in df['article_text']:
    sentences.append(sent_tokenize(s))

# Flatten the list of sentences
sentences = [y for x in sentences for y in x]

# Load word embeddings (replace with your actual path and file)
word_embeddings = {}
with open('/kaggle/input/d/nithinreddy90/glove6b/glove.6B.300d.txt', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        word_embeddings[word] = coefs

# Function to create sentence vectors (handles zero-length sentences)
def create_sentence_vector(sentence: str):
    if len(sentence.split()) == 0:
        return np.zeros((300,))
    else:
        word_vectors = [word_embeddings.get(word, np.zeros((300,))) for word in sentence.split()]
        return np.sum(word_vectors, axis=0) / (len(word_vectors) + 0.001)  # Avoid division by zero

# Create sentence vectors
sentence_vectors = [create_sentence_vector(sentence) for sentence in sentences]

# Calculate cosine similarity matrix
sim_mat = cosine_similarity(sentence_vectors)

# Create a network graph from the similarity matrix
G = nx.from_numpy_array(sim_mat)

# Calculate PageRank scores for sentences
scores = nx.pagerank(G)

# Rank sentences based on PageRank scores
ranked_sentences = sorted(
    ((score, sentence) for score, sentence in zip(scores.values(), sentences)),
    reverse=True)

# Print ranked sentences
print("Ranked sentences (higher score indicates more relevant):")
for score, sentence in ranked_sentences:
    print(f"- Score: {score:.4f}, Sentence: {sentence}")

# Print a random article and its summary
i = random.randint(0, len(df))

print(colored("ARTICLE".center(50), 'yellow'))
print('\n')
print(colored(df['article_text'][i], 'blue'))
print('\n')
print(colored("SUMMARY:".center(50), 'green'))
print('\n')
print(colored(' '.join([sentence for score, sentence in ranked_sentences[:5]]), 'cyan'))
# Out:
# Ranked sentences (higher score indicates more relevant):
# - Score: 0.0093, Sentence: `` Clearly make life difficult , still I 6-2 , 3-1 , break points , things could ended quickly today , even though I n't best serve percentage stats .
# - Score: 0.0092, Sentence: Speaking Swiss Indoors tournament play Sundays final Romanian qualifier Marius Copil , world number three said given impossibly short time frame make decision , opted commitment .
# - Score: 0.0091, Sentence: Major players feel big event late November combined one January Australian Open mean much tennis little rest .
# - Score: 0.0091, Sentence: The Spaniard broke Anderson twice second n't get another chance South African 's serve final set .
# - Score: 0.0091, Sentence: `` I felt like best weeks I get know players I playing Fed Cup weeks Olympic weeks , necessarily tournaments .
# - Score: 0.0091, Sentence: Federer easier time previous match Medvedev , three-setter Shanghai two weeks ago .
# - Score: 0.0090, Sentence: When I 'm courts I 'm court playing , I 'm competitor I want beat every single person whether 're locker room across net.So I 'm one strike conversation weather know next minutes I go try win tennis match .
# - Score: 0.0090, Sentence: Because always easy last weeks . ''
# - Score: 0.0090, Sentence: `` We also impression stage might better play matches train .
# - Score: 0.0090, Sentence: He came two rounds qualifying last weekend reach Basel main draw , including beating Zverev 's older brother , Mischa .
# - Score: 0.0090, Sentence: `` Not always , I really feel like mid-2000 years huge shift attitudes top players friendly giving , lot players like Roger coming .
# - Score: 0.0090, Sentence: Federer handed difficult draw could could come across Kevin Anderson , Novak Djokovic Rafael Nadal latter rounds .
# - Score: 0.0089, Sentence: `` I know 's maybe last title , today I try lot absorb enjoy moments much consciously .
# - Score: 0.0089, Sentence: `` I felt good week better every day .
# - Score: 0.0089, Sentence: Uhm , I 'm really friendly close many players .
# - Score: 0.0089, Sentence: Djokovic could play Marco Cecchinato second round .
# - Score: 0.0089, Sentence: The end season finally sight , many players defending , losing , huge chunks points Singapore , Zhuhai London , podcast co-hosts Nina Pantic Irina Falconi discuss art defending points ( 02:14 ) .
# - Score: 0.0089, Sentence: It 's big deal never forget first .
# - Score: 0.0089, Sentence: `` On Monday , I free look I feel , '' Federer said winning Swiss Indoors .
# - Score: 0.0089, Sentence: But stands , Federer draw scheduled face either former world No 3 Milos Raonic Jo-Wilfried Tsonga second round .
# - Score: 0.0089, Sentence: The world No 1 forced miss Spain 's Davis Cup clash France Asian hard court season .
# - Score: 0.0089, Sentence: Kei Nishikori try end long losing streak ATP finals Kevin Anderson go second title year Erste Bank Open Sunday .
# - Score: 0.0089, Sentence: Currently ninth place , Nishikori win could move within 125 points cut eight-man event London next month .
# - Score: 0.0088, Sentence: `` And even though maybe smaller teams , I still think kept quite bit .
# - Score: 0.0088, Sentence: Federer 's success Basel last week ninth time hometown tournament .
# - Score: 0.0088, Sentence: `` I n't serve well [ first-round opponent Filip Kranjovic , '' Federer said .
# - Score: 0.0088, Sentence: `` I could make decision time , I told wanted . ''
# - Score: 0.0088, Sentence: He used first break point close first set going 3-0 second wrapping win first match point .
# - Score: 0.0088, Sentence: `` They left three days decide '' , Federer said .
# - Score: 0.0088, Sentence: Federer , 37 , first broke tour two decades ago since gone enjoy glittering career .
# - Score: 0.0088, Sentence: The Paris Masters draw made Nadal start campaign Tuesday Wednesday either Fernando Verdasco Jeremy Chardy .
# - Score: 0.0088, Sentence: Meanwhile , Federer hoping improve service game hunts ninth Swiss Indoors title week .
# - Score: 0.0088, Sentence: `` I felt like really kind changed people little bit , definitely 90s , lot quiet , , started become better . ''
# - Score: 0.0088, Sentence: He could lose 1,400 points next weeks , instead focusing negative , perspective ( 06:28 ) .
# - Score: 0.0087, Sentence: It makes incredibly happy win home tournament make people happy .
# - Score: 0.0087, Sentence: Federer 's projected route Paris final could also lead matches Kevin Anderson Novak Djokovic .
# - Score: 0.0087, Sentence: `` But maybe 's exactly caught eventually .
# - Score: 0.0087, Sentence: `` And long I fear injury , I play . ''
# - Score: 0.0087, Sentence: Nishikori held serve throughout Kukushkin , came qualifying .
# - Score: 0.0087, Sentence: I think 're sport n't mean friends everyone 're categorized , 're tennis player , 're going get along tennis players .
# - Score: 0.0087, Sentence: Davenport enjoyed success late 1990s third final major tournament win came 2000 Australian Open .
# - Score: 0.0087, Sentence: Nadal 's appearance Paris big boost tournament organisers could see Roger Federer withdraw .
# - Score: 0.0087, Sentence: It 's getting used .
# - Score: 0.0087, Sentence: `` Maybe I celebrate last title .
# - Score: 0.0087, Sentence: He dropped serve love , let another match point slip Medvedev 's next service game netting backhand .
# - Score: 0.0087, Sentence: `` On Tuesday I fly Paris train afternoon ready first match Wednesday night .
# - Score: 0.0087, Sentence: `` I n't like kind pressure , '' Federer said deadline Kosmos handed .
# - Score: 0.0086, Sentence: `` My children , parents , sister team , '' Federer added .
# - Score: 0.0086, Sentence: `` I highly doubt , course .
# - Score: 0.0086, Sentence: Copil two also beating No .
# - Score: 0.0086, Sentence: Two players , Stefanos Tsitsipas Kyle Edmund , first career ATP titles last week ( 13:26 ) .
# - Score: 0.0086, Sentence: `` I think really nice environment great atmosphere , especially veteran players helping younger players .
# - Score: 0.0086, Sentence: A winner 11 ATP events , Nishikori n't triumphed since winning Memphis February 2016 .
# - Score: 0.0086, Sentence: When said really close lot players , something strategic ?
# - Score: 0.0086, Sentence: Federer action Swiss Indoors Basel reaches final , could pull Paris bid stay fresh London .
# - Score: 0.0086, Sentence: `` It means world .
# - Score: 0.0086, Sentence: But first 20-time Grand Slam winner wants train Paris Masters court afternoon deciding whether appear opening match either Milos Raonic Jo-Wilfried Tsonga .
# - Score: 0.0086, Sentence: The Russian player problems openly speaking recent interview said : 'I n't really hide feelings much .
# - Score: 0.0086, Sentence: Let 's also forget two Grand Slam doubles triumphs season .
# - Score: 0.0086, Sentence: In Singapore , one biggest storylines ( aside matches , course ) on-court coaching debate .
# - Score: 0.0086, Sentence: Federer said earlier month Shanghai chances playing Davis Cup non-existent .
# - Score: 0.0085, Sentence: 'No , .
# - Score: 0.0085, Sentence: There many things 're interested , . '
# - Score: 0.0085, Sentence: The Romanian aims first title arriving Basel without career win top-10 opponent .
# - Score: 0.0085, Sentence: `` It 's pleasant atmosphere , I 'd say , around locker rooms .
# - Score: 0.0085, Sentence: `` It seems pretty friendly right , '' said Davenport .
# - Score: 0.0085, Sentence: The competition set feature 18 countries November 18-24 finals Madrid next year , replace classic home-and-away ties played four times per year decades .
# - Score: 0.0085, Sentence: We see happens , '' said .
# - Score: 0.0084, Sentence: With victory Sunday , Anderson qualify ATP Finals .
# - Score: 0.0084, Sentence: Kosmos headed Barcelona footballer Gerard Pique , hoping fellow Spaniard Rafael Nadal play upcoming event .
# - Score: 0.0084, Sentence: Seeking ninth title hometown event , 99th overall , Federer play 93th-ranked Marius Copil Sunday .
# - Score: 0.0084, Sentence: This first rounds tricky . ''
# - Score: 0.0084, Sentence: `` There touching moments : seeing ball children , standing ovations , familiar faces audience .
# - Score: 0.0084, Sentence: I say hellos , I 'm sending players flowers well .
# - Score: 0.0084, Sentence: I friends completely different jobs interests , I 've met different parts life .
# - Score: 0.0084, Sentence: But claims mentality professional tennis players slowly began change new millennium .
# - Score: 0.0083, Sentence: He lost eight straight finals since .
# - Score: 0.0083, Sentence: British No 1 Kyle Edmund 12th seed Paris get underway round two either Karen Khachanov Filip Krajinovic .
# - Score: 0.0083, Sentence: But ultimately tennis small part .
# - Score: 0.0083, Sentence: `` I think I misfiring corners , I hitting lines enough .
# - Score: 0.0083, Sentence: Nishikori leads Anderson 4-2 career matchups , South African previous meeting year .
# - Score: 0.0083, Sentence: I think everyone thinks 're tennis players greatest friends .
# - Score: 0.0083, Sentence: Nadal could play defending champion Jack Sock third round potential quarter-final either Borna Coric Dominic Thiem .
# - Score: 0.0083, Sentence: `` I think designed , anyhow .
# - Score: 0.0083, Sentence: Anderson shot fifth career title second year winning New York February .
# - Score: 0.0083, Sentence: I lot friends away courts . '
# - Score: 0.0082, Sentence: Is different men 's tour women 's tour ?
# - Score: 0.0082, Sentence: `` It always emotional thank team .
# - Score: 0.0082, Sentence: Nina Irina give opinions coaching look like future , tours ( 18:55 ) .
# - Score: 0.0082, Sentence: But ATP World Tour Finals due begin next month , Nadal ready prove fitness season-ending event 02 Arena .
# - Score: 0.0082, Sentence: This designed future generation players . ''
# - Score: 0.0082, Sentence: 6 Marin Cilic second round .
# - Score: 0.0082, Sentence: I think every person different interests .
# - Score: 0.0082, Sentence: Federer dominated 20th-ranked Medvedev first match-point chance break serve 5-1 .
# - Score: 0.0082, Sentence: Argentina Britain received wild cards new-look event , compete along four 2018 semi-finalists 12 teams win qualifying rounds next February .
# - Score: 0.0081, Sentence: Irina looks back WTA title win Bogota 2016 , tells unforgettable story semifinal drama ( 14:04 ) .
# - Score: 0.0081, Sentence: Roger Federer revealed organisers re-launched condensed Davis Cup gave three days decide would commit controversial competition .
# - Score: 0.0081, Sentence: Against Verdasco , Anderson hit nine 19 aces opening set .
# - Score: 0.0081, Sentence: It 's secret Jack Sock struggled singles court year ( record 7-19 ) .
# - Score: 0.0081, Sentence: `` I n't time consult people I consult .
# - Score: 0.0081, Sentence: Copil fired 26 aces past Zverev never dropped serve , clinching 2 1/2 hours forehand volley winner break Zverev second time semifinal .
# - Score: 0.0081, Sentence: Maria Sharapova basically friends tennis players WTA Tour .
# - Score: 0.0081, Sentence: Federer Swiss Indoors last week beating Romanian qualifier Marius Copil final .
# - Score: 0.0081, Sentence: I think everyone knows job .
# - Score: 0.0078, Sentence: Novak Djokovic said give precedence ATP 's intended re-launch defunct World Team Cup January 2020 , various Australian venues .
# - Score: 0.0078, Sentence: I 'm pretty competitive girl .
# - Score: 0.0077, Sentence: Nadal flew Paris Friday footage Paris Masters official Twitter account shows Spaniard smiling strides onto court practice .
# - Score: 0.0076, Sentence: Nadal played tennis since forced retire US Open semi-finals Juan Martin Del Porto knee injury .
# - Score: 0.0076, Sentence: And delighted watched family friends purchased 60 tickets final dearest .
# - Score: 0.0076, Sentence: The 20-time Grand Slam champion voiced doubts wisdom one-week format introduced organisers Kosmos , promised International Tennis Federation $ 3 billion prize money next quarter-century .
# - Score: 0.0076, Sentence: The 20-time Grand Slam winner chasing 99th ATP title Swiss Indoors week faces Jan-Lennard Struff second round Thursday ( 6pm BST ) .
# - Score: 0.0075, Sentence: BASEL , Switzerland ( AP ) , Roger Federer advanced 14th Swiss Indoors final career beating seventh-seeded Daniil Medvedev 6-1 , 6-4 Saturday .
# - Score: 0.0073, Sentence: The 37-year-old claimed 99th ATP title hunting century French capital week .
# - Score: 0.0072, Sentence: Copil upset expectations Federer final Alexander Zverev 6-3 , 6-7 ( 6 ) , 6-4 win fifth-ranked German earlier semifinal .
# - Score: 0.0070, Sentence: He clinched fourth chance Medvedev netted baseline .
# - Score: 0.0069, Sentence: And sometimes tilts emotions , sometimes I stumble .
# - Score: 0.0064, Sentence: The fifth-seeded Nishikori reached third final 2018 beating Mikhail Kukushkin Kazakhstan 6-4 , 6-3 semifinals .
# - Score: 0.0055, Sentence: Tennis giveth , tennis taketh away .
# - Score: 0.0051, Sentence: The second-seeded Anderson defeated Fernando Verdasco 6-3 , 3-6 , 6-4 .
#                      ARTICLE
#
#
# Federer , 37 , first broke tour two decades ago since gone enjoy glittering career . The 20-time Grand Slam winner chasing 99th ATP title Swiss Indoors week faces Jan-Lennard Struff second round Thursday ( 6pm BST ) . Davenport enjoyed success late 1990s third final major tournament win came 2000 Australian Open . But claims mentality professional tennis players slowly began change new millennium . `` It seems pretty friendly right , '' said Davenport . `` I think really nice environment great atmosphere , especially veteran players helping younger players . `` It 's pleasant atmosphere , I 'd say , around locker rooms . `` I felt like best weeks I get know players I playing Fed Cup weeks Olympic weeks , necessarily tournaments . `` And even though maybe smaller teams , I still think kept quite bit . `` Not always , I really feel like mid-2000 years huge shift attitudes top players friendly giving , lot players like Roger coming . `` I felt like really kind changed people little bit , definitely 90s , lot quiet , , started become better . '' Meanwhile , Federer hoping improve service game hunts ninth Swiss Indoors title week . `` I n't serve well [ first-round opponent Filip Kranjovic , '' Federer said . `` I think I misfiring corners , I hitting lines enough . `` Clearly make life difficult , still I 6-2 , 3-1 , break points , things could ended quickly today , even though I n't best serve percentage stats . `` But maybe 's exactly caught eventually . It 's getting used . This first rounds tricky . ''
#
#
#                      SUMMARY:
#
#
# `` Clearly make life difficult , still I 6-2 , 3-1 , break points , things could ended quickly today , even though I n't best serve percentage stats . Speaking Swiss Indoors tournament play Sundays final Romanian qualifier Marius Copil , world number three said given impossibly short time frame make decision , opted commitment . Major players feel big event late November combined one January Australian Open mean much tennis little rest . The Spaniard broke Anderson twice second n't get another chance South African 's serve final set . `` I felt like best weeks I get know players I playing Fed Cup weeks Olympic weeks , necessarily tournaments .
